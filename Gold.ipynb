# %%
pip install --pre pycaret
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.1/480.1 KB 15.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.0/213.0 KB 22.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 11.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 65.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 KB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 KB 4.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
# !pip install pycaret
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install --force-reinstall numpy==1.19
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 44.7 MB/s eta 0:00:00
# ERROR: Operation cancelled by user

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/Training Data.csv")
from pycaret.regression import *
#We have two target columns. We will remove the T+14 day Target
data_22= data.drop(['Gold-T+14'],axis=1)

# %%
a=setup(data_22,target='Gold-T+22',
        ignore_features=['Date'],session_id=11,profile=False);
# Out:
# <style type="text/css">
# #T_56097_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_56097_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_56097_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_56097_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_56097_row0_col1" class="data row0 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_56097_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_56097_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_56097_row1_col1" class="data row1 col1" >Gold-T+22</td>
#     </tr>
#     <tr>
#       <th id="T_56097_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
compare_models(turbo=True)
# Out:
# <style type="text/css">
# #T_e1bd4_ th {
#   text-align: left;
# }
# ...

# %%
knn = create_model('knn')
# Out:
# <style type="text/css">
# #T_2cfac_row10_col0, #T_2cfac_row10_col1, #T_2cfac_row10_col2, #T_2cfac_row10_col3, #T_2cfac_row10_col4, #T_2cfac_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_2cfac_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
# ...

# %%
et = create_model('et')
# Out:
# <style type="text/css">
# #T_229c2_row10_col0, #T_229c2_row10_col1, #T_229c2_row10_col2, #T_229c2_row10_col3, #T_229c2_row10_col4, #T_229c2_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_229c2_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
# ...

# %%
evaluate_model(knn)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
evaluate_model(et)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
#b=setup(data_22,target='Gold-T+22',
 #       ignore_features=['Date'],session_id=11,
  #      profile=False,remove_outliers=True);
# Out:
# <style type="text/css">
# #T_e9038_row9_col1, #T_e9038_row13_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e9038_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e9038_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e9038_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e9038_row0_col1" class="data row0 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_e9038_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e9038_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e9038_row1_col1" class="data row1 col1" >Gold-T+22</td>
#     </tr>
#     <tr>
#       <th id="T_e9038_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
#et = create_model('et')

# %%
#knn = create_model('knn')

# %%
blend_knn_et = blend_models(estimator_list=[knn,et])
# Out:
# <style type="text/css">
# #T_f27c5_row10_col0, #T_f27c5_row10_col1, #T_f27c5_row10_col2, #T_f27c5_row10_col3, #T_f27c5_row10_col4, #T_f27c5_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_f27c5_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
# ...

# %%
save_config
# Out:
# <function pycaret.regression.save_config(file_name: str)>

# %%
save_model(blend_knn_et,'22Day Regressor')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=/tmp/joblib),
#           steps=[('clean_column_names',
#                   TransformerWrapper(transformer=CleanColumnNames())),
#                  ('numerical_imputer',
#                   TransformerWrapper(include=['Unnamed: 0', 'Gold-T-1',
#                                               'Silver-T-1', 'Crude Oil-T-1',
#                                               'S&P500-T-1',
#                                               'Russel 2000 Index-T-1',
#                                               '10 Yr US T-Note futures-T-1',
#                                               '2 Yr US T-Note Futures-T-1',
#                                               'Platinum-T-1', 'Copper-T-1',
#                                               'Dolla...
#                  ('categorical_imputer',
#                   TransformerWrapper(include=[],
# ...

# %%
data = pd.read_csv("/content/tdata.csv")
data.dtypes
# Out:
# Unnamed: 0             int64
# Date                  object
# Gold-T-1             float64
# Silver-T-1           float64
# Crude Oil-T-1        float64
#                       ...
# Gold                 float64
# Silver               float64
# Crude Oil            float64
# S&P500               float64
# Russel 2000 Index    float64
# Length: 114, dtype: object

# %%
#Importing Libraries
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt

data = pd.read_csv("/content/tdata.csv")
from pycaret.regression import *

#Loading the stored model
regressor_22 = load_model("22Day Regressor");
#Making Predictions
predicted_return_22 = predict_model(regressor_22,data=data)
predicted_return_22=predicted_return_22[['Date','Gold-T-21']]
predicted_return_22.columns = ['Date','Return_22']
#Adding return Predictions to Gold Values
predicted_values = data[['Date', 'Gold']]
predicted_values = predicted_values.tail(len(predicted_return_22))
predicted_values = pd.merge(left=predicted_values,right=predicted_return_22,on=['Date'],how='inner')
predicted_values['Gold-T+22']=(predicted_values['Gold']*(1+predicted_values['Return_22'])).round(decimals =1)
#Adding T+22 Date
from datetime import datetime, timedelta
#Preparing Date Range
end_date= datetime.strftime(datetime.today(),'%Y-%m-%d')
start_date = "2019-10-11"
date_range = pd.bdate_range(start=start_date,end=end_date)
data = pd.DataFrame({ 'Date': date_range})
data['Date']=pd.to_datetime(data['Date'],format='%Y-%b-%d')

predicted_values.tail()
# Out:
# Transformation Pipeline and Model Successfully Loaded
#           Date    Gold  Return_22  Gold-T+22
# 74  23-01-2020  1564.6   0.055379     1651.2
# 75  24-01-2020  1571.1   0.040946     1635.4
# 76  27-01-2020  1576.8   0.041617     1642.4
# 77  28-01-2020  1569.2   0.036118     1625.9
# 78  29-01-2020  1569.8   0.033103     1621.8
